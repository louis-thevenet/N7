# %% [markdown]
# # Introduction à la librairie Keras

# %% [markdown]
# Dans le TP précédent, vous avez implémenté l'apprentissage et l'inférence d'un réseau de neurones. En pratique, il est plus courant de faire appel à des librairies qui masquent la complexité de ces algorithmes (notamment le calcul des gradients, réalisé par différentiation automatique). Dans la suite, nous utiliserons pour les TPs la librairie ***Keras***. Dans un premier temps, pour ce TP nous allons détailler sur un exemple simple (le même que pour le TP précédent) les différentes étapes à mettre en place pour entraîner un réseau à l'aide de cette librairie.

# %% [markdown]
# Le bloc de code ci-dessous sera utile pour analyser l'évolution des performances au cours de l'apprentissage

# %%
def plot_training_analysis(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  #plt.figure()
  plt.subplots(1, 2, figsize=(10, 4))


  plt.subplot(1,2,1)
  plt.plot(epochs, acc, 'b', linestyle="--",label='Training acc')
  plt.plot(epochs, val_acc, 'g', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.subplot(1,2,2)
  plt.plot(epochs, loss, 'b', linestyle="--",label='Training loss')
  plt.plot(epochs, val_loss,'g', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

# %% [markdown]
# ## Exemple de classification binaire simple

# %% [markdown]
# Chargement des données (ce sont les mêmes que lors du dernier TP)

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

# Génération des données
x, y = datasets.make_blobs(n_samples=250, n_features=2, centers=2, center_box=(- 3, 3), random_state=1)
# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')

plt.xlabel('x1')
plt.ylabel('x2')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')

plt.legend()
plt.show()

# %% [markdown]
# Dans ce problème, les données $x^{(i)}$ sont les points, on a donc $x^{(i)} \in \mathbb{R}^2$. Les étiquettes $y^{(i)}$ correspondent à la couleur des points (bleue ou rouge), matérialisée par un label (0 ou 1).
#
# Pour résoudre le problème, on peut donc construire un perceptron monocouche à 2 entrées et une sortie.
#
# <center>
# <img src="https://drive.google.com/uc?id=1WfUL0fTE7fjeHMrlGjgH3b_3511ttnO8">
# </center>
#
# Il s'agit d'un problème de classification binaire, il faut donc utiliser une fonction d'activation **sigmoide** sur la couche de sortie.

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Définition du modèle, un simple perceptron monocouche.
model = Sequential() # Dans un modèle séquentiel, on peut ajouter les couches les unes après les autres
# Ici, on définit une seule couche connectant 2 neurones d'entrée à un neurone de sortie, portant une activation sigmoide
model.add(Dense(1, activation='sigmoid', input_dim=2)) # input_dim indique la dimension de la couche d'entrée, ici 2

model.summary() # affiche un résumé du modèle
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
# =================================================================
# Total params: 3 (12.00 Byte)
# Trainable params: 3 (12.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Le résumé du modèle (*summary*) nous indique le nombre de paramètres du modèle, ici 3 : 2 poids synaptiques et un biais.
#
# Il nous faut maintenant choisir la fonction de coût : pour ce problème de classification binaire, le choix standard est l'entropie croisée binaire (*binary cross-entropy*).
#
# On choisit dans un premier temps un optimiseur standard, la descente de gradient stochastique.

# %%
from tensorflow.keras import optimizers

# Définition de l'optimiseur
sgd = optimizers.SGD(learning_rate=0.1) # On choisit la descente de gradient stochastique, avec un taux d'apprentissage de 0.1

# On définit ici, pour le modèle introduit plus tôt, l'optimiseur choisi (la SGD), la fonction de perte (ici
# l'entropie croisée binaire pour un problème de classification binaire) et les métriques que l'on veut observer pendant
# l'entraînement. L'accuracy désigne le pourcentage de bonnes classification, et est un indicateur plus simple à interpréter que l'entropie croisée.
model.compile(optimizer=sgd,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle avec des mini-batchs de taille 20, sur 15 epochs.
# Le paramètre validation_split signifie qu'on tire aléatoirement une partie des données
# (ici 20%) pour servir d'ensemble de validation
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15, batch_size=20)

plot_training_analysis(history)
# Out:
# Epoch 1/15
# 12/12 [==============================] - 1s 24ms/step - loss: 0.4684 - accuracy: 0.8400 - val_loss: 0.3345 - val_accuracy: 0.9600
# Epoch 2/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2748 - accuracy: 0.9244 - val_loss: 0.2684 - val_accuracy: 0.9600
# Epoch 3/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2312 - accuracy: 0.9333 - val_loss: 0.2342 - val_accuracy: 0.9600
# Epoch 4/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2066 - accuracy: 0.9378 - val_loss: 0.2097 - val_accuracy: 0.9600
# Epoch 5/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1893 - accuracy: 0.9422 - val_loss: 0.1910 - val_accuracy: 0.9600
# Epoch 6/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1759 - accuracy: 0.9644 - val_loss: 0.1769 - val_accuracy: 0.9600
# Epoch 7/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1652 - accuracy: 0.9644 - val_loss: 0.1655 - val_accuracy: 0.9600
# Epoch 8/15
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1572 - accuracy: 0.9689 - val_loss: 0.1563 - val_accuracy: 0.9600
# Epoch 9/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1506 - accuracy: 0.9644 - val_loss: 0.1488 - val_accuracy: 1.0000
# Epoch 10/15
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1448 - accuracy: 0.9644 - val_loss: 0.1418 - val_accuracy: 1.0000
# Epoch 11/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1401 - accuracy: 0.9644 - val_loss: 0.1357 - val_accuracy: 1.0000
# Epoch 12/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1357 - accuracy: 0.9644 - val_loss: 0.1307 - val_accuracy: 1.0000
# Epoch 13/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1317 - accuracy: 0.9644 - val_loss: 0.1263 - val_accuracy: 1.0000
# Epoch 14/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1285 - accuracy: 0.9644 - val_loss: 0.1225 - val_accuracy: 1.0000
# Epoch 15/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1252 - accuracy: 0.9644 - val_loss: 0.1192 - val_accuracy: 1.0000

# %% [markdown]
# L'apprentissage semble bien se passer : la perte d'apprentissage et la perte de validation décroissent au cours du temps, et l'accuracy est proche de 100% à la fin de l'apprentissage.
#
# La cellule suivante introduit une fonction permettant de visualiser la frontière de décision du modèle appris.

# %%
import numpy as np
def print_decision_boundaries(model, x, y):
  dx, dy = 0.1, 0.1
  y_grid, x_grid = np.mgrid[slice(np.min(x[:,1]), np.max(x[:,1]) + dy, dy),
                  slice(np.min(x[:,0]), np.max(x[:,0]) + dx, dx)]


  x_gen = np.concatenate((np.expand_dims(np.reshape(x_grid, (-1)),1),np.expand_dims(np.reshape(y_grid, (-1)),1)), axis=1)
  z_gen = model.predict(x_gen).reshape(x_grid.shape)

  z_min, z_max = 0, 1

  c = plt.pcolor(x_grid, y_grid, z_gen, cmap='RdBu', vmin=z_min, vmax=z_max)
  plt.colorbar(c)
  plt.plot(x[y==0,0], x[y==0,1], 'r.')
  plt.plot(x[y==1,0], x[y==1,1], 'b.')
  plt.show()

# %%
print_decision_boundaries(model, x_train, y_train)
# Out:
# 198/198 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Exemple de classification plus "complexe"

# %% [markdown]
# Les données de la section précédente sont linéairement séparables : un séparateur linéaire suffit à obtenir des bonnes performances, et un perceptron monocouche est donc bien adapté à la résolution de ce problème.
#
# Traitons maintenant un second problème légèrement plus
# complexe, non linéairement séparable.

# %%
x, y = datasets.make_gaussian_quantiles(n_samples=250, n_features=2, n_classes=2, random_state=1)
# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')

plt.xlabel('x1')
plt.ylabel('x2')

plt.legend()
plt.show()

# %% [markdown]
# **Travail à faire** : commencez par tester un perceptron monocouche comme nous l'avons vu précédemment.

# %%
model = Sequential() # Dans un modèle séquentiel, on peut ajouter les couches les unes après les autres
# Ici, on définit une seule couche connectant 2 neurones d'entrée à un neurone de sortie, portant une activation sigmoide
model.add(Dense(1, activation='sigmoid', input_dim=2)) # input_dim indique la dimension de la couche d'entrée, ici 2

# Définition de l'optimiseur
sgd = optimizers.SGD(learning_rate=0.1) # On choisit la descente de gradient stochastique, avec un taux d'apprentissage de 0.1

# On définit ici, pour le modèle introduit plus tôt, l'optimiseur choisi (la SGD), la fonction de perte (ici
# l'entropie croisée binaire pour un problème de classification binaire) et les métriques que l'on veut observer pendant
# l'entraînement. L'accuracy désigne le pourcentage de bonnes classification, et est un indicateur plus simple à interpréter que l'entropie croisée.
model.compile(optimizer=sgd,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle avec des mini-batchs de taille 20, sur 15 epochs.
# Le paramètre validation_split signifie qu'on tire aléatoirement une partie des données
# (ici 20%) pour servir d'ensemble de validation
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15, batch_size=20)

plot_training_analysis(history)
# Out:
# Epoch 1/15
# 12/12 [==============================] - 1s 20ms/step - loss: 0.8567 - accuracy: 0.4933 - val_loss: 0.6850 - val_accuracy: 0.5600
# Epoch 2/15
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7893 - accuracy: 0.4978 - val_loss: 0.6729 - val_accuracy: 0.5600
# Epoch 3/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7467 - accuracy: 0.4978 - val_loss: 0.6684 - val_accuracy: 0.6000
# Epoch 4/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7161 - accuracy: 0.4933 - val_loss: 0.6709 - val_accuracy: 0.5600
# Epoch 5/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7007 - accuracy: 0.5156 - val_loss: 0.6761 - val_accuracy: 0.5200
# Epoch 6/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6939 - accuracy: 0.4667 - val_loss: 0.6794 - val_accuracy: 0.4800
# Epoch 7/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6905 - accuracy: 0.4756 - val_loss: 0.6815 - val_accuracy: 0.5600
# Epoch 8/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6889 - accuracy: 0.4844 - val_loss: 0.6832 - val_accuracy: 0.5600
# Epoch 9/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6890 - accuracy: 0.4933 - val_loss: 0.6860 - val_accuracy: 0.5200
# Epoch 10/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6879 - accuracy: 0.5022 - val_loss: 0.6861 - val_accuracy: 0.5200
# Epoch 11/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6879 - accuracy: 0.5111 - val_loss: 0.6857 - val_accuracy: 0.5200
# Epoch 12/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6875 - accuracy: 0.4978 - val_loss: 0.6861 - val_accuracy: 0.6000
# Epoch 13/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6869 - accuracy: 0.5422 - val_loss: 0.6883 - val_accuracy: 0.6000
# Epoch 14/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6869 - accuracy: 0.5556 - val_loss: 0.6886 - val_accuracy: 0.6000
# Epoch 15/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6868 - accuracy: 0.5778 - val_loss: 0.6901 - val_accuracy: 0.6400

# %% [markdown]
# Un perceptron monocouche ne permet que d'obtenir un séparateur linéaire, ce qui n'est pas suffisant pour apprendre à séparer ces données. La **capacité** du modèle est trop faible, et on est dans une situation de **sous-apprentissage** : la perte d'apprentissage ne diminue pas suffisamment, le modèle n'arrive pas à apprendre correctement l'ensemble d'apprentissage.
#
# Pour résoudre ce problème, il faut ajouter (au moins) une couche cachée au modèle. Voici un exemple ci-dessous, où l'on ajoute une couche cachée à 2 neurones.
#
# **Travail à faire** : testez l'entraînement de ce modèle, et au besoin ajustez le nombre de neurones de la couche cachée pour obtenir de bons résultats.
#
# **Travail à faire** : testez également de remplacer l'optimiseur SGD par l'optimiseur [Adam](https://keras.io/api/optimizers/adam/)

# %%
model = Sequential() # Dans un modèle séquentiel, on peut ajouter les couches les unes après les autres
# Ici, on définit une seule couche connectant 2 neurones d'entrée à un neurone de sortie, portant une activation sigmoide
model.add(Dense(8, activation='relu', input_dim=2)) # input_dim indique la dimension de la couche d'entrée, ici 2
model.add(Dense(1, activation='sigmoid')) # input_dim indique la dimension de la couche d'entrée, ici 2

# Définition de l'optimiseur
adam = optimizers.Adam(learning_rate=0.1) # On choisit la descente de gradient stochastique, avec un taux d'apprentissage de 0.1

# On définit ici, pour le modèle introduit plus tôt, l'optimiseur choisi (la SGD), la fonction de perte (ici
# l'entropie croisée binaire pour un problème de classification binaire) et les métriques que l'on veut observer pendant
# l'entraînement. L'accuracy désigne le pourcentage de bonnes classification, et est un indicateur plus simple à interpréter que l'entropie croisée.
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle avec des mini-batchs de taille 20, sur 15 epochs.
# Le paramètre validation_split signifie qu'on tire aléatoirement une partie des données
# (ici 20%) pour servir d'ensemble de validation
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15, batch_size=20)

plot_training_analysis(history)
print_decision_boundaries(model, x_train, y_train)
# Out:
# Epoch 1/15
# 12/12 [==============================] - 1s 22ms/step - loss: 0.6179 - accuracy: 0.6667 - val_loss: 0.5264 - val_accuracy: 0.6800
# Epoch 2/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4541 - accuracy: 0.8000 - val_loss: 0.3990 - val_accuracy: 0.8000
# Epoch 3/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3045 - accuracy: 0.9111 - val_loss: 0.2694 - val_accuracy: 0.8800
# Epoch 4/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2156 - accuracy: 0.9467 - val_loss: 0.1658 - val_accuracy: 0.9600
# Epoch 5/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1892 - accuracy: 0.9244 - val_loss: 0.1344 - val_accuracy: 0.9600
# Epoch 6/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1638 - accuracy: 0.9378 - val_loss: 0.1976 - val_accuracy: 0.9200
# Epoch 7/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1660 - accuracy: 0.9200 - val_loss: 0.2767 - val_accuracy: 0.8400
# Epoch 8/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1467 - accuracy: 0.9422 - val_loss: 0.2347 - val_accuracy: 0.9200
# Epoch 9/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1460 - accuracy: 0.9467 - val_loss: 0.5208 - val_accuracy: 0.8000
# Epoch 10/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1901 - accuracy: 0.9067 - val_loss: 0.1094 - val_accuracy: 0.9200
# Epoch 11/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1304 - accuracy: 0.9422 - val_loss: 0.3426 - val_accuracy: 0.8800
# Epoch 12/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1483 - accuracy: 0.9289 - val_loss: 0.1815 - val_accuracy: 0.9200
# Epoch 13/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1310 - accuracy: 0.9289 - val_loss: 0.2004 - val_accuracy: 0.9200
# Epoch 14/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0927 - accuracy: 0.9778 - val_loss: 0.2128 - val_accuracy: 0.8800
# Epoch 15/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0917 - accuracy: 0.9822 - val_loss: 0.1552 - val_accuracy: 0.9200
# 96/96 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Sur-apprentissage et régularisation

# %% [markdown]
# Dans cette section, nous commençons par altérer un peu les données afin qu'elles comportent du "bruit" : la frontière de décision entre données bleues et rouges n'est plus si claire.

# %%
x, y = datasets.make_gaussian_quantiles(n_samples=250, n_features=2, n_classes=2, random_state=1)
x[y==0] = x[y==0]*1.2
x[y==1] = x[y==1]*0.8

# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')

plt.xlabel('x1')
plt.ylabel('x2')

plt.legend()

plt.show()

# %% [markdown]
# **Travail à faire** : Reprenez le modèle à une couche cachée construit précédemment et vérifiez que ce modèle arrive toujours à apprendre une solution satisfaisante.

# %%
model = Sequential() # Dans un modèle séquentiel, on peut ajouter les couches les unes après les autres
# Ici, on définit une seule couche connectant 2 neurones d'entrée à un neurone de sortie, portant une activation sigmoide
model.add(Dense(16, activation='relu', input_dim=2)) # input_dim indique la dimension de la couche d'entrée, ici 2
model.add(Dense(1, activation='sigmoid')) # input_dim indique la dimension de la couche d'entrée, ici 2

# Définition de l'optimiseur
adam = optimizers.Adam(learning_rate=0.1) # On choisit la descente de gradient stochastique, avec un taux d'apprentissage de 0.1

# On définit ici, pour le modèle introduit plus tôt, l'optimiseur choisi (la SGD), la fonction de perte (ici
# l'entropie croisée binaire pour un problème de classification binaire) et les métriques que l'on veut observer pendant
# l'entraînement. L'accuracy désigne le pourcentage de bonnes classification, et est un indicateur plus simple à interpréter que l'entropie croisée.
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle avec des mini-batchs de taille 20, sur 15 epochs.
# Le paramètre validation_split signifie qu'on tire aléatoirement une partie des données
# (ici 20%) pour servir d'ensemble de validation
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15, batch_size=20)

plot_training_analysis(history)
print_decision_boundaries(model, x_train, y_train)
# Out:
# Epoch 1/15
# 12/12 [==============================] - 1s 33ms/step - loss: 0.6752 - accuracy: 0.5422 - val_loss: 0.5922 - val_accuracy: 0.7600
# Epoch 2/15
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6064 - accuracy: 0.6800 - val_loss: 0.5680 - val_accuracy: 0.6400
# Epoch 3/15
# 12/12 [==============================] - 0s 16ms/step - loss: 0.5558 - accuracy: 0.6978 - val_loss: 0.4886 - val_accuracy: 0.7600
# Epoch 4/15
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5329 - accuracy: 0.7244 - val_loss: 0.5279 - val_accuracy: 0.7200
# Epoch 5/15
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5523 - accuracy: 0.7067 - val_loss: 0.6095 - val_accuracy: 0.7200
# Epoch 6/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5843 - accuracy: 0.6622 - val_loss: 0.4571 - val_accuracy: 0.8000
# Epoch 7/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4806 - accuracy: 0.7244 - val_loss: 0.4649 - val_accuracy: 0.7200
# Epoch 8/15
# 12/12 [==============================] - 0s 9ms/step - loss: 0.4920 - accuracy: 0.7600 - val_loss: 0.5170 - val_accuracy: 0.7200
# Epoch 9/15
# 12/12 [==============================] - 0s 9ms/step - loss: 0.4957 - accuracy: 0.7467 - val_loss: 0.4646 - val_accuracy: 0.7200
# Epoch 10/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4984 - accuracy: 0.7467 - val_loss: 0.4492 - val_accuracy: 0.8000
# Epoch 11/15
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5397 - accuracy: 0.7333 - val_loss: 0.5425 - val_accuracy: 0.7200
# Epoch 12/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4870 - accuracy: 0.6933 - val_loss: 0.4392 - val_accuracy: 0.7600
# Epoch 13/15
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4656 - accuracy: 0.7867 - val_loss: 0.4707 - val_accuracy: 0.6800
# Epoch 14/15
# 12/12 [==============================] - 0s 11ms/step - loss: 0.4518 - accuracy: 0.7511 - val_loss: 0.4919 - val_accuracy: 0.6800
# Epoch 15/15
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4571 - accuracy: 0.7600 - val_loss: 0.4832 - val_accuracy: 0.6800
# 62/62 [==============================] - 0s 1ms/step

# %% [markdown]
# L'avantage de ce modèle à une couche cachée est qu'il reste assez simple : il n'a pas une capacité suffisante pour chercher à expliquer à tout prix la distribution des données d'apprentissage. L'accuracy plafonne vers 75% sur l'ensemble d'apprentissage, ce qui semble évoquer du sous-apprentissage, mais en réalité le modèle est satisfaisant car l'accuracy de validation est elle autour de 70%.
#
#
# Une piste d'amélioration pourrait consister à augmenter la capacité du modèle afin d'obtenir de meilleures performances sur l'ensemble d'apprentissage.
#
# **Travail à faire** : Augmentez la capacité du modèle (nombre de couches cachées, nombre de neurones par couche) de sorte d'obtenir une accuracy d'apprentissage d'environ 90%. Qu'observez-vous sur l'accuracy de validation ?

# %%
model = Sequential() # Dans un modèle séquentiel, on peut ajouter les couches les unes après les autres
# Ici, on définit une seule couche connectant 2 neurones d'entrée à un neurone de sortie, portant une activation sigmoide
model.add(Dense(100, activation='relu', input_dim=2)) # input_dim indique la dimension de la couche d'entrée, ici 2
model.add(Dense(100, activation='relu')) # input_dim indique la dimension de la couche d'entrée, ici 2
model.add(Dense(100, activation='relu')) # input_dim indique la dimension de la couche d'entrée, ici 2
model.add(Dense(1, activation='sigmoid')) # input_dim indique la dimension de la couche d'entrée, ici 2

# Définition de l'optimiseur
adam = optimizers.Adam(learning_rate=0.01) # On choisit la descente de gradient stochastique, avec un taux d'apprentissage de 0.1

# On définit ici, pour le modèle introduit plus tôt, l'optimiseur choisi (la SGD), la fonction de perte (ici
# l'entropie croisée binaire pour un problème de classification binaire) et les métriques que l'on veut observer pendant
# l'entraînement. L'accuracy désigne le pourcentage de bonnes classification, et est un indicateur plus simple à interpréter que l'entropie croisée.
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle avec des mini-batchs de taille 20, sur 15 epochs.
# Le paramètre validation_split signifie qu'on tire aléatoirement une partie des données
# (ici 20%) pour servir d'ensemble de validation
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=150, batch_size=20)

plot_training_analysis(history)
print_decision_boundaries(model, x_train, y_train)
# Out:
# Epoch 1/150
# 12/12 [==============================] - 2s 32ms/step - loss: 0.6673 - accuracy: 0.5556 - val_loss: 0.6653 - val_accuracy: 0.6400
# Epoch 2/150
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6152 - accuracy: 0.6889 - val_loss: 0.5962 - val_accuracy: 0.6000
# Epoch 3/150
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5527 - accuracy: 0.6889 - val_loss: 0.5175 - val_accuracy: 0.6800
# Epoch 4/150
# 12/12 [==============================] - 0s 10ms/step - loss: 0.4920 - accuracy: 0.7156 - val_loss: 0.4279 - val_accuracy: 0.7600
# Epoch 5/150
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5064 - accuracy: 0.7378 - val_loss: 0.5180 - val_accuracy: 0.6000
# Epoch 6/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4788 - accuracy: 0.7333 - val_loss: 0.6286 - val_accuracy: 0.7200
# Epoch 7/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4886 - accuracy: 0.7556 - val_loss: 0.4608 - val_accuracy: 0.6400
# Epoch 8/150
# 12/12 [==============================] - 0s 8ms/step - loss: 0.
150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3951 - accuracy: 0.7733 - val_loss: 0.4420 - val_accuracy: 0.6800
# Epoch 128/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4285 - accuracy: 0.7644 - val_loss: 0.5540 - val_accuracy: 0.6000
# Epoch 129/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3887 - accuracy: 0.8000 - val_loss: 0.6087 - val_accuracy: 0.6400
# Epoch 130/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4076 - accuracy: 0.8222 - val_loss: 0.7967 - val_accuracy: 0.6000
# Epoch 131/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3815 - accuracy: 0.7956 - val_loss: 0.4258 - val_accuracy: 0.6400
# Epoch 132/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3475 - accuracy: 0.8311 - val_loss: 0.4879 - val_accuracy: 0.7600
# Epoch 133/150
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3209 - accuracy: 0.8311 - val_loss: 0.5356 - val_accuracy: 0.6800
# Epoch 134/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3199 - accuracy: 0.8311 - val_loss: 0.6377 - val_accuracy: 0.6400
# Epoch 135/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3376 - accuracy: 0.8133 - val_loss: 0.5896 - val_accuracy: 0.6400
# Epoch 136/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3383 - accuracy: 0.8356 - val_loss: 0.4847 - val_accuracy: 0.6800
# Epoch 137/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3352 - accuracy: 0.8178 - val_loss: 0.5751 - val_accuracy: 0.6400
# Epoch 138/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3160 - accuracy: 0.8444 - val_loss: 0.5950 - val_accuracy: 0.7600
# Epoch 139/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3135 - accuracy: 0.8489 - val_loss: 0.8972 - val_accuracy: 0.6400
# Epoch 140/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3222 - accuracy: 0.8178 - val_loss: 0.5542 - val_accuracy: 0.6800
# Epoch 141/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2991 - accuracy: 0.8444 - val_loss: 0.4938 - val_accuracy: 0.6800
# Epoch 142/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2868 - accuracy: 0.8667 - val_loss: 0.6520 - val_accuracy: 0.6400
# Epoch 143/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2733 - accuracy: 0.8489 - val_loss: 0.6273 - val_accuracy: 0.6800
# Epoch 144/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2762 - accuracy: 0.8533 - val_loss: 0.8268 - val_accuracy: 0.6800
# Epoch 145/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3681 - accuracy: 0.8133 - val_loss: 0.6636 - val_accuracy: 0.7200
# Epoch 146/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4033 - accuracy: 0.7556 - val_loss: 0.8857 - val_accuracy: 0.7200
# Epoch 147/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3470 - accuracy: 0.7822 - val_loss: 0.8859 - val_accuracy: 0.7600
# Epoch 148/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3440 - accuracy: 0.8133 - val_loss: 0.8332 - val_accuracy: 0.6800
# Epoch 149/150
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3067 - accuracy: 0.8444 - val_loss: 0.9091 - val_accuracy: 0.6800
# Epoch 150/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2991 - accuracy: 0.8489 - val_loss: 1.0575 - val_accuracy: 0.6000
# 62/62 [==============================] - 0s 2ms/step

# %% [markdown]
# On observe du **sur-apprentissage** ! L'accuracy d'entrainement est élevée, mais l'accuracy de validation est faible. On doit alors chercher à limiter le sur-apprentissage, et pour ce faire on peut utiliser des techniques de régularisation. Une des techniques vues en cours consiste à appliquer une pénalité sur la norme des paramètres du modèle. Ainsi, plutôt que de minimiser une fonction objectif $J(\theta)$ classique :
# $$ J(\theta) = \frac{1}{n} \sum_{i=1}^{n} \text{loss}(y^{(i)}, \hat{y}^{(i)}) $$
#
# on minimise plutôt :
# $$ J(\theta) = \frac{1}{n} \sum_{i=1}^{n} \text{loss}(y^{(i)}, \hat{y}^{(i)}) + \lambda \sum_{j=1}^M \theta_j^2 $$
#
# où $M$ désigne le nombre de paramètres (poids synaptiques et biais) du réseau, $\theta$ désigne les paramètres du réseau.
#
# En pratique il suffit d'appliquer cette pénalisation aux poids synaptiques seuls (car ils sont beaucoup plus nombreux).
#
# La librairie Keras permet d'appliquer de la régularisation à n'importe quelle couche, [comme décrit sur cette page.](https://keras.io/api/layers/regularizers/)
#
# **Travail à faire**: Reprenez votre réseau précédent (avec lequel on obtenait du sur-apprentissage) et intégrez de la régularisation pour limiter le sur-apprentissage.

# %%
from keras import regularizers


model = Sequential() # Dans un modèle séquentiel, on peut ajouter les couches les unes après les autres
# Ici, on définit une seule couche connectant 2 neurones d'entrée à un neurone de sortie, portant une activation sigmoide
model.add(Dense(
    100,
    activation='relu',
    input_dim=2,
    kernel_regularizer=regularizers.L1L2(l1=1e-4, l2=1e-3),
    bias_regularizer=regularizers.L2(1e-4),
    activity_regularizer=regularizers.L2(1e-5)
    ))

model.add(Dense(
    100,
    activation='relu',
    kernel_regularizer=regularizers.L1L2(l1=1e-4, l2=1e-3),
    bias_regularizer=regularizers.L2(1e-4),
    activity_regularizer=regularizers.L2(1e-5)
    ))


model.add(Dense(
    100,
    activation='relu',
    kernel_regularizer=regularizers.L1L2(l1=1e-4, l2=1e-3),
    bias_regularizer=regularizers.L2(1e-4),
    activity_regularizer=regularizers.L2(1e-5)
    ))

model.add(Dense(1, activation='sigmoid')) # input_dim indique la dimension de la couche d'entrée, ici 2

# Définition de l'optimiseur
adam = optimizers.Adam(learning_rate=0.01) # On choisit la descente de gradient stochastique, avec un taux d'apprentissage de 0.1

# On définit ici, pour le modèle introduit plus tôt, l'optimiseur choisi (la SGD), la fonction de perte (ici
# l'entropie croisée binaire pour un problème de classification binaire) et les métriques que l'on veut observer pendant
# l'entraînement. L'accuracy désigne le pourcentage de bonnes classification, et est un indicateur plus simple à interpréter que l'entropie croisée.
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Entraînement du modèle avec des mini-batchs de taille 20, sur 15 epochs.
# Le paramètre validation_split signifie qu'on tire aléatoirement une partie des données
# (ici 20%) pour servir d'ensemble de validation
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=150, batch_size=20)

plot_training_analysis(history)
print_decision_boundaries(model, x_train, y_train)
# Out:
# Epoch 1/150
# 12/12 [==============================] - 2s 29ms/step - loss: 0.9041 - accuracy: 0.5644 - val_loss: 0.7255 - val_accuracy: 0.8000
# Epoch 2/150
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6810 - accuracy: 0.7289 - val_loss: 0.6540 - val_accuracy: 0.6400
# Epoch 3/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6641 - accuracy: 0.7022 - val_loss: 0.5740 - val_accuracy: 0.7200
# Epoch 4/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5750 - accuracy: 0.7467 - val_loss: 0.6070 - val_accuracy: 0.7200
# Epoch 5/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5311 - accuracy: 0.7556 - val_loss: 0.5016 - val_accuracy: 0.8000
# Epoch 6/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5416 - accuracy: 0.7733 - val_loss: 0.6064 - val_accuracy: 0.6400
# Epoch 7/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5539 - accuracy: 0.7111 - val_loss: 0.5284 - val_accuracy: 0.7200
# Epoch 8/150
# 12/12 [==============================] - 0s 8ms/step - loss: 0.
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4591 - accuracy: 0.7689 - val_loss: 0.5025 - val_accuracy: 0.7200
# Epoch 127/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4503 - accuracy: 0.7467 - val_loss: 0.4984 - val_accuracy: 0.7600
# Epoch 128/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4447 - accuracy: 0.7822 - val_loss: 0.5435 - val_accuracy: 0.7200
# Epoch 129/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4592 - accuracy: 0.7511 - val_loss: 0.4669 - val_accuracy: 0.6800
# Epoch 130/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4449 - accuracy: 0.7378 - val_loss: 0.5613 - val_accuracy: 0.6800
# Epoch 131/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4481 - accuracy: 0.7511 - val_loss: 0.4515 - val_accuracy: 0.7600
# Epoch 132/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4607 - accuracy: 0.7511 - val_loss: 0.5676 - val_accuracy: 0.6800
# Epoch 133/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4578 - accuracy: 0.7378 - val_loss: 0.4747 - val_accuracy: 0.7600
# Epoch 134/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4373 - accuracy: 0.7911 - val_loss: 0.5470 - val_accuracy: 0.6800
# Epoch 135/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4543 - accuracy: 0.7733 - val_loss: 0.4511 - val_accuracy: 0.8000
# Epoch 136/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4679 - accuracy: 0.7422 - val_loss: 0.5067 - val_accuracy: 0.7200
# Epoch 137/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4476 - accuracy: 0.7600 - val_loss: 0.4735 - val_accuracy: 0.7600
# Epoch 138/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4438 - accuracy: 0.7956 - val_loss: 0.4833 - val_accuracy: 0.7200
# Epoch 139/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4620 - accuracy: 0.7689 - val_loss: 0.4520 - val_accuracy: 0.7600
# Epoch 140/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4511 - accuracy: 0.7778 - val_loss: 0.4837 - val_accuracy: 0.6800
# Epoch 141/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4487 - accuracy: 0.7733 - val_loss: 0.5484 - val_accuracy: 0.7200
# Epoch 142/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4344 - accuracy: 0.7689 - val_loss: 0.4802 - val_accuracy: 0.7600
# Epoch 143/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4348 - accuracy: 0.7778 - val_loss: 0.5417 - val_accuracy: 0.6800
# Epoch 144/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4521 - accuracy: 0.7556 - val_loss: 0.4444 - val_accuracy: 0.7600
# Epoch 145/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5408 - accuracy: 0.7244 - val_loss: 0.4929 - val_accuracy: 0.8000
# Epoch 146/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5217 - accuracy: 0.6978 - val_loss: 0.4989 - val_accuracy: 0.7200
# Epoch 147/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5087 - accuracy: 0.7422 - val_loss: 0.4951 - val_accuracy: 0.7600
# Epoch 148/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4773 - accuracy: 0.7511 - val_loss: 0.5086 - val_accuracy: 0.6800
# Epoch 149/150
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4664 - accuracy: 0.7511 - val_loss: 0.5229 - val_accuracy: 0.7200
# Epoch 150/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4528 - accuracy: 0.7600 - val_loss: 0.5121 - val_accuracy: 0.7200
# 62/62 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Problème à 3 classes
#
# Tous les problèmes que nous avons abordés jusqu'à maintenant étaient des problèmes de classification binaire (fonction d'activation sigmoide).
#
# Dans cette section nous définissons un jeu de données comportant trois classes.

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets
import matplotlib.pyplot as plt

# Génération des données
x, y = datasets.make_blobs(n_samples=500, n_features=2, centers=3, center_box=(- 5, 5), random_state=3)
# Partitionnement des données en apprentissage et test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=1)

# Affichage des données d'apprentissage
plt.plot(x_train[y_train==0,0], x_train[y_train==0,1], 'b.', label='Apprentissage, classe 0')
plt.plot(x_train[y_train==1,0], x_train[y_train==1,1], 'r.', label='Apprentissage, classe 1')
plt.plot(x_train[y_train==2,0], x_train[y_train==2,1], 'g.', label='Apprentissage, classe 2')

plt.xlabel('x1')
plt.ylabel('x2')

# Affichage des données de test
plt.plot(x_test[y_test==0,0], x_test[y_test==0,1], 'b+', label='Test, classe 0')
plt.plot(x_test[y_test==1,0], x_test[y_test==1,1], 'r+', label='Test, classe 1')
plt.plot(x_test[y_test==2,0], x_test[y_test==2,1], 'g+', label='Test, classe 1')

plt.legend()
plt.show()

# %% [markdown]
# La fonction ci-dessous permet d'afficher les frontières de décision apprises par le modèle.

# %%
def print_decision_boundaries_3classes(model, x, y):
    # Adjust step sizes to match the input data
    dx = (np.max(x[:, 0]) - np.min(x[:, 0])) / 100
    dy = (np.max(x[:, 1]) - np.min(x[:, 1])) / 100

    # Create a grid with adjusted step sizes
    y_grid, x_grid = np.mgrid[slice(np.min(x[:, 1]), np.max(x[:, 1]) + dy, dy),
                               slice(np.min(x[:, 0]), np.max(x[:, 0]) + dx, dx)]

    # Generate points for prediction
    x_gen = np.stack((x_grid.ravel(), y_grid.ravel()), axis=-1)
    y_pred_gen = np.argmax(model.predict(x_gen), axis=1)
    z_gen = y_pred_gen.reshape(x_grid.shape)

    # Define color range
    z_min, z_max = 0, 2

    # Plot decision boundaries
    c = plt.pcolor(x_grid, y_grid, z_gen, cmap='brg', vmin=z_min, vmax=z_max, alpha=0.5)
    plt.colorbar(c)

    # Plot data points for each class
    plt.plot(x[y == 0, 0], x[y == 0, 1], 'bo', label='Class 0')
    plt.plot(x[y == 1, 0], x[y == 1, 1], 'ro', label='Class 1')
    plt.plot(x[y == 2, 0], x[y == 2, 1], 'go', label='Class 2')

    # Add legend
    plt.legend()
    plt.show()

# %% [markdown]
# Lorsque les données appartiennent à plus de deux classes, il est nécessaire de formater les labels sous la forme de *one-hot vectors*, c'est-à-dire de de vecteurs constitués de 0 et d'un 1 à l'indice de la classe correspondante.
#
# Ainsi, pour un problème à 3 classes :
# - si $x^{(i)}$ appartient à la classe 0, $y^{(i)} = [1, 0, 0]^T$
# - si $x^{(i)}$ appartient à la classe 1, $y^{(i)} = [0, 1, 0]^T$
# - si $x^{(i)}$ appartient à la classe 2, $y^{(i)} = [0, 0, 1]^T$
#
# Dans le jeu de données introduit plus haut, les labels $y \in \{0, 1, 2\}$. Pour les convertir au format *one-hot*, vous pouvez utiliser la fonction [to_categorical](https://www.tensorflow.org/api_docs/python/tf/keras/utils/to_categorical).
#
# **Travail à faire**: Construisez un perceptron monocouche capable de résoudre ce problème de classification à 3 classes.

# %%
from tensorflow.keras.utils import to_categorical
model = Sequential()
model.add(Dense(3, activation='softmax', input_dim=2))

adam = optimizers.Adam(learning_rate=0.1)
model.compile(optimizer=adam,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, to_categorical(y_train), validation_data=(x_test, to_categorical(y_test)), epochs=15, batch_size=20)

plot_training_analysis(history)
print_decision_boundaries_3classes(model, x_train, y_train)
# Out:
# Epoch 1/15
# 23/23 [==============================] - 1s 18ms/step - loss: 0.5836 - accuracy: 0.7400 - val_loss: 0.4196 - val_accuracy: 0.8200
# Epoch 2/15
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2618 - accuracy: 0.8956 - val_loss: 0.3532 - val_accuracy: 0.8400
# Epoch 3/15
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2128 - accuracy: 0.9311 - val_loss: 0.3112 - val_accuracy: 0.8600
# Epoch 4/15
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2067 - accuracy: 0.9178 - val_loss: 0.2695 - val_accuracy: 0.8800
# Epoch 5/15
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1846 - accuracy: 0.9422 - val_loss: 0.2415 - val_accuracy: 0.9200
# Epoch 6/15
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1773 - accuracy: 0.9467 - val_loss: 0.2537 - val_accuracy: 0.9200
# Epoch 7/15
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1773 - accuracy: 0.9378 - val_loss: 0.2459 - val_accuracy: 0.9200
# Epoch 8/15
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1745 - accuracy: 0.9511 - val_loss: 0.2185 - val_accuracy: 0.9200
# Epoch 9/15
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1657 - accuracy: 0.9511 - val_loss: 0.2211 - val_accuracy: 0.9200
# Epoch 10/15
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1702 - accuracy: 0.9444 - val_loss: 0.2175 - val_accuracy: 0.9200
# Epoch 11/15
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1641 - accuracy: 0.9444 - val_loss: 0.1995 - val_accuracy: 0.9200
# Epoch 12/15
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1634 - accuracy: 0.9489 - val_loss: 0.2029 - val_accuracy: 0.9200
# Epoch 13/15
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1691 - accuracy: 0.9533 - val_loss: 0.2421 - val_accuracy: 0.9000
# Epoch 14/15
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1666 - accuracy: 0.9422 - val_loss: 0.2140 - val_accuracy: 0.9200
# Epoch 15/15
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1722 - accuracy: 0.9378 - val_loss: 0.2197 - val_accuracy: 0.8800
# 322/322 [==============================] - 0s 1ms/step

# %% [markdown]
# # Application à une base de données réelle
#
# Pour mettre en application les notions vues précédemment, téléchargez les données suivantes.

# %%
# !wget acarlier.fr/tp/HA_dataset.csv
# Out:
# --2024-04-02 07:13:18--  http://acarlier.fr/tp/HA_dataset.csv
# Resolving acarlier.fr (acarlier.fr)... 212.194.248.69, 2a02:842a:5e:4701:b48a:fe3:257b:3972
# Connecting to acarlier.fr (acarlier.fr)|212.194.248.69|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://acarlier.fr/tp/HA_dataset.csv [following]
# --2024-04-02 07:13:18--  https://acarlier.fr/tp/HA_dataset.csv
# Connecting to acarlier.fr (acarlier.fr)|212.194.248.69|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11328 (11K) [application/octet-stream]
# Saving to: ‘HA_dataset.csv’
#
# HA_dataset.csv      100%[===================>]  11.06K  --.-KB/s    in 0s
#
# 2024-04-02 07:13:19 (336 MB/s) - ‘HA_dataset.csv’ saved [11328/11328]

# %%
import csv
from sklearn.model_selection import train_test_split

x = []
y = []

# Lecture du fichier CSV et des données
with open('HA_dataset.csv', 'r') as file:
    reader = csv.reader(file)
    headers = next(reader)  # Ligne d'en-tête
    for row in reader:
        x.append([float(value) for value in row[:-1]])  # Toutes les colonnes à l'exception de la dernières sont les variables d'entrée
        y.append(int(row[-1]))  # La dernière colonne constitue le label à prédire

x = np.array(x)
y = np.array(y)

# Séparation des données en jeux d'apprentissage et de test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Affichage de la dimension des données
print("Dimension de x_train:", x_train.shape)
print("Dimension de y_train:", y_train.shape)
print("Dimension de x_test:", x_test.shape)
print("Dimension de y_test:", y_test.shape)
# Out:
# Dimension de x_train: (242, 13)
# Dimension de y_train: (242,)
# Dimension de x_test: (61, 13)
# Dimension de y_test: (61,)

# %% [markdown]
# Ces données sont issues de https://archive.ics.uci.edu/dataset/45/heart+disease et regroupent des caractéristiques de patients risquant ($y=1$) de développer une attaque cardiaque. Voici les différentes caractéristiques sur lesquelles votre modèle pourra s'appuyer pour établir un pronostic :
# - *age* : Âge du patient
# - *sex* : Sexe du patient (0-1)
# - *exang* : Angine induite par l'exercice (1 = oui ; 0 = non)
# - *ca* : Nombre de vaisseaux principaux (0-3)
# - *cp* : Type de douleur thoracique (1-4)
# - *trestbps* : Pression artérielle au repos (en mm de mercure)
# - *chol* : Cholestérol en mg/dl récupéré via un capteur BMI
# - *fbs* : (glycémie à jeun > 120 mg/dl) (1 = vrai ; 0 = faux)
# - *restecg* : Résultats électrocardiographiques au repos (0-2)
# - *thalach* : Fréquence cardiaque maximale atteinte
# - *oldpeak* : Dépression du segment ST induite par l'exercice par rapport au repos
# - *slope*, *thal* : signification non renseignée

# %% [markdown]
# **Travail à faire** : Construisez un classifieur permettant d'obtenir les meilleurs résultats possibles sur l'ensemble de test de ce jeu de données.
#
#
# **N.B.** Prenez garde à l'échelle des données d'entrée ! Le code ci-dessous vous permettra de les répresenter sous forme graphique. Il peut être intéressant de les normaliser...

# %%
import matplotlib.pyplot as plt


combined_data = np.column_stack((x_train, y_train))
combined_data_transposed = list(map(list, zip(*combined_data)))

# Création d'un "diagramme à moustache"
plt.figure(figsize=(10, 6))
plt.boxplot(combined_data_transposed, labels=headers[:-1] + ['target'])
plt.xticks(rotation=45)
plt.title('Distribution des valeurs de chacune des variables')
plt.xlabel('Variables')
plt.ylabel('Valeurs')
plt.yscale('log')  # Echelle logarithmique

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt


x_train = x_train / x_train.max(axis=0)
x_test = x_test / x_test.max(axis=0)



combined_data = np.column_stack((x_train, y_train))
combined_data_transposed = list(map(list, zip(*combined_data)))

# Création d'un "diagramme à moustache"
plt.figure(figsize=(10, 6))
plt.boxplot(combined_data_transposed, labels=headers[:-1] + ['target'])
plt.xticks(rotation=45)
plt.title('Distribution des valeurs de chacune des variables')
plt.xlabel('Variables')
plt.ylabel('Valeurs')
plt.yscale('log')  # Echelle logarithmique

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.utils import to_categorical

model = Sequential()
model.add(Dense(50, activation='relu', input_dim=13))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

adam = optimizers.Adam(learning_rate=0.1)
model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, validation_data=(x_test,y_test), epochs=35, batch_size=20)

plot_training_analysis(history)
# Out:
# Epoch 1/35
# 13/13 [==============================] - 2s 33ms/step - loss: 1.6744 - accuracy: 0.5579 - val_loss: 0.6710 - val_accuracy: 0.5902
# Epoch 2/35
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6423 - accuracy: 0.5992 - val_loss: 0.5259 - val_accuracy: 0.8033
# Epoch 3/35
# 13/13 [==============================] - 0s 10ms/step - loss: 0.5014 - accuracy: 0.7975 - val_loss: 0.4236 - val_accuracy: 0.7869
# Epoch 4/35
# 13/13 [==============================] - 0s 12ms/step - loss: 0.4374 - accuracy: 0.7975 - val_loss: 0.4132 - val_accuracy: 0.8525
# Epoch 5/35
# 13/13 [==============================] - 0s 11ms/step - loss: 0.4254 - accuracy: 0.8058 - val_loss: 0.3879 - val_accuracy: 0.8689
# Epoch 6/35
# 13/13 [==============================] - 0s 7ms/step - loss: 0.